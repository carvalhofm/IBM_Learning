# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ***Fabio M Carvalho***
#
# Economist

# %% [markdown]
# *I want to become a Data Scientist. I like to data and solve problems*

# %% [markdown]
# ### This following code test if the number is even

# %%
import random

def even(n):
    return ("Is the number: "+ str(n) + " even ? " + str(n%2 ==0))

even(random.randint(0,3000))
# Out:
# 'Is the number: 2501 even ? False'

# %% [markdown]
# This is my ***table***
#
# | **_Number_** | **_Rest For 2_** | **_Is Even_**  |
# | :--- |:---:| :---:|
# | 10 | 0 | Yes |
# | 11 | 1 | ~~NO~~ |
# | 12 | 0 | Yes |
# | 13 | 1 | ~~NO~~ |
#
# * For acess this page click [here](https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/1e8971e3-1542-469a-ad8f-d969886440d3/view?access_token=f34ab27023252ff4723017a99155e84e67ed075d42ba8078cfde24d8769f3e53).
